# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Load data (food items and their descriptions)
food_df = pd.read_csv('food.csv')

food_df
# Out:
#    food_id                         title  \
# 0   food01                  Cheeseburger
# 1   food02                 Veggie Burger
# 2   food03           Double Cheeseburger
# 3   food04            Bacon Cheeseburger
# 4   food05         Mushroom Swiss Burger
# 5   food06      Grilled Chicken Sandwich
# 6   food07                  BLT Sandwich
# 7   food08        Fried Chicken Sandwich
# 8   food09  Spicy Fried Chicken Sandwich
# 9   food10       Grilled Cheese Sandwich
# 10  food11                 Fried Chicken
# 11  food12               Chicken Tenders
# 12  food13                 Chicken Wings
# 13  food14         Nashville Hot Chicken
# 14  food15               Popcorn Chicken
# 15  food16               Pepperoni Pizza
# 16  food17              Margherita Pizza
# 17  food18                Hawaiian Pizza
# 18  food19             BBQ Chicken Pizza
# 19  food20                  Veggie Pizza
# 20  food21                    Beef Tacos
# 21  food22               Chicken Burrito
# 22  food23                    Fish Tacos
# 23  food24                Veggie Burrito
# 24  food25                  Shrimp Tacos
# 25  food26                    Beef Tacos
# 26  food27               Chicken Burrito
# 27  food28                    Fish Tacos
# 28  food29                Veggie Burrito
# 29  food30                  Shrimp Tacos
# 30  food31                  French Fries
# 31  food32                   Onion Rings
# 32  food33             Mozzarella Sticks
# 33  food34                  Garlic Bread
# 34  food35                Mac and Cheese
# 35  food36                Chocolate Cake
# 36  food37                    Cheesecake
# 37  food38                Brownie Sundae
# 38  food39                    Fruit Tart
# 39  food40                     Ice Cream
# 40  food41                          Coke
# 41  food42                        Sprite
# 42  food43                      Iced Tea
# 43  food44                      Lemonade
# 44  food45                 Bottled Water
#
#                                           description  price  image  \
# 0   Juicy beef patty with melted cheddar cheese, l...  325.0    NaN
# 1   Grilled veggie patty with lettuce, tomato, and...  300.0    NaN
# 2   Two juicy beef patties with melted cheddar che...  450.0    NaN
# 3   Juicy beef patty with crispy bacon, melted che...  375.0    NaN
# 4   Juicy beef patty with sautéed mushrooms, melte...  375.0    NaN
# 5   Grilled chicken breast with lettuce, tomato, a...  325.0    NaN
# 6   Crispy bacon with lettuce, tomato, and mayo on...  275.0    NaN
# 7   Crispy fried chicken breast with lettuce, toma...  325.0    NaN
# 8   Crispy fried chicken breast with spicy mayo, l...  350.0    NaN
# 9            Melted American cheese on grilled bread.  250.0    NaN
# 10  Crispy fried chicken with your choice of dippi...  375.0    NaN
# 11  Tender strips of breaded chicken with your cho...  350.0    NaN
# 12  Crispy fried chicken wings with your choice of...  400.0    NaN
# 13  Spicy fried chicken with coleslaw and pickles ...  425.0    NaN
# 14         Bite-sized pieces of crispy fried chicken.  300.0    NaN
# 15  Classic pizza topped with tomato sauce, mozzar...  450.0    NaN
# 16  Pizza topped with tomato sauce, mozzarella che...  400.0    NaN
# 17  Pizza topped with tomato sauce, mozzarella che...  475.0    NaN
# 18  Pizza topped with barbecue sauce, mozzarella c...  500.0    NaN
# 19  Pizza topped with tomato sauce, mozzarella che...  450.0    NaN
# 20  Two tacos with seasoned ground beef, lettuce, ...  325.0    NaN
# 21  Grilled chicken, rice, beans, lettuce, tomato,...  375.0    NaN
# 22  Two tacos with fried fish, lettuce, tomato, an...  350.0    NaN
# 23  Grilled vegetables, rice, beans, lettuce, toma...  350.0    NaN
# 24  Two tacos with sautéed shrimp, lettuce, tomato...  400.0    NaN
# 25  Two tacos with seasoned ground beef, lettuce, ...  325.0    NaN
# 26  Grilled chicken, rice, beans, lettuce, tomato,...  375.0    NaN
# 27  Two tacos with fried fish, lettuce, tomato, an...  350.0    NaN
# 28  Grilled vegetables, rice, beans, lettuce, toma...  350.0    NaN
# 29  Two tacos with sautéed shrimp, lettuce, tomato...  400.0    NaN
# 30                               Crispy golden fries.  150.0    NaN
# 31                        Crispy breaded onion rings.  200.0    NaN
# 32  Breaded and fried mozzarella sticks with marin...  250.0    NaN
# 33                  Toasted bread with garlic butter.  175.0    NaN
# 34   Classic mac and cheese with creamy cheese sauce.  300.0    NaN
# 35       Rich chocolate cake with chocolate frosting.  275.0    NaN
# 36  Creamy New York-style cheesecake with graham c...  300.0    NaN
# 37  Warm chocolate brownie with vanilla ice cream ...  325.0    NaN
# 38  Pastry crust filled with vanilla custard and t...  350.0    NaN
# 39                   Two scoops of vanilla ice cream.  200.0    NaN
# 40                            12 oz can of Coca-Cola.   75.0    NaN
# 41                               12 oz can of Sprite.   75.0    NaN
# 42                16 oz cup of fresh-brewed iced tea.  100.0    NaN
# 43            16 oz cup of freshly squeezed lemonade.  125.0    NaN
# 44                  16.9 oz bottle of purified water.   50.0    NaN
#
#    category_id
# 0        cat01
# 1        cat01
# 2        cat01
# 3        cat01
# 4        cat01
# 5        cat02
# 6        cat02
# 7        cat02
# 8        cat02
# 9        cat02
# 10       cat03
# 11       cat03
# 12       cat03
# 13       cat03
# 14       cat03
# 15       cat04
# 16       cat04
# 17       cat04
# 18       cat04
# 19       cat04
# 20       cat05
# 21       cat05
# 22       cat05
# 23       cat05
# 24       cat05
# 25       cat06
# 26       cat06
# 27       cat06
# 28       cat06
# 29       cat06
# 30       cat07
# 31       cat07
# 32       cat07
# 33       cat07
# 34       cat07
# 35       cat08
# 36       cat08
# 37       cat08
# 38       cat08
# 39       cat08
# 40       cat09
# 41       cat09
# 42       cat09
# 43       cat09
# 44       cat09

# %%
# Create TF-IDF vectors for food descriptions
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(food_df['description'])

X
# Out:
# <45x125 sparse matrix of type '<class 'numpy.float64'>'
# 	with 459 stored elements in Compressed Sparse Row format>

# %%
# Compute cosine similarity between food items
cosine_similarities = cosine_similarity(X)

# Define function to recommend similar food items
def recommend_items(food_item, cosine_similarities, food_df, top_n=5):
    item_index = food_df[food_df['title'] == food_item].index[0]
    similar_items = list(enumerate(cosine_similarities[item_index]))
    sorted_similar_items = sorted(similar_items, key=lambda x: x[1], reverse=True)
    top_similar_items = [food_df.iloc[i[0]]['title'] for i in sorted_similar_items[1:top_n+1]]
    return top_similar_items
# Out:
# Recommended items for Cheeseburger: ['Bacon Cheeseburger', 'Double Cheeseburger', 'Mushroom Swiss Burger', 'Veggie Burger', 'Beef Tacos']

# %%
# Input food item
food_item = input("Enter the food item based which you want top 5 recommended food:\n\n")
recommended_items = recommend_items(food_item, cosine_similarities, food_df)

print()
print("-------"*10)
print(f"Recommended food items for '{food_item}' are:\n") 
c = 0
for i in recommended_items:
    c += 1
    print(f"{c}. {i}")
print("-------"*10)
# Out:
# Enter the food item based which you want top 5 recommended food:
#
# Grilled Chicken Sandwich
#
# ----------------------------------------------------------------------
# Recommended food items for 'Grilled Chicken Sandwich' are:
#
# 1. Fried Chicken Sandwich
# 2. Spicy Fried Chicken Sandwich
# 3. BLT Sandwich
# 4. Nashville Hot Chicken
# 5. Veggie Burger
# ----------------------------------------------------------------------

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Load data (food items and their descriptions)
food_df = pd.read_csv('food.csv')
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(food_df['description'])

# Compute cosine similarity between food items
cosine_similarities = cosine_similarity(X)

# Define function to recommend similar food items
def recommend_items(food_item, cosine_similarities, food_df, top_n=5):
    item_index = food_df[food_df['title'] == food_item].index[0]
    similar_items = list(enumerate(cosine_similarities[item_index]))
    sorted_similar_items = sorted(similar_items, key=lambda x: x[1], reverse=True)
    top_similar_items = [food_df.iloc[i[0]]['title'] for i in sorted_similar_items[1:top_n+1]]
    return top_similar_items

# Input food item
food_item = input("Enter the food item based which you want top 5 recommended food:\n\n")
recommended_items = recommend_items(food_item, cosine_similarities, food_df)

print()
print("-------"*10)
print(f"Recommended food items for '{food_item}' are:\n") 
c = 0
for i in recommended_items:
    c += 1
    print(f"{c}. {i}")
print("-------"*10)
# Out:
# Enter the food item based which you want top 5 recommended food:
#
# Grilled Chicken Sandwich
#
# ----------------------------------------------------------------------
# Recommended food items for 'Grilled Chicken Sandwich' are:
#
# 1. Fried Chicken Sandwich
# 2. Spicy Fried Chicken Sandwich
# 3. BLT Sandwich
# 4. Nashville Hot Chicken
# 5. Veggie Burger
# ----------------------------------------------------------------------
